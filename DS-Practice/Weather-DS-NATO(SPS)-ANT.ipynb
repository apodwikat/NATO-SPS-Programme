# %%
from IPython.display import Image
img_path = r"C:\Users\hp\Pictures\Screenshots\Screenshot 2024-08-07 134548.png"
Image(filename=img_path, width=1000, height=1500)

# %% [markdown]
# # Weather forecasts & (SST) - NATO Science for Peace and Security (SPS) Programme

# %% [markdown]
# ## Abdallah I. J. Dwikat - Computer Engineering - Intern at NATO (SPS) Programme

# %% [markdown]
# #### The goal from this directory is to have a clean weather dataset for Antalya province that will be used later on for differnet Machine Learning Models. (The data collected on daily basis over 17 years between 2007 and 2023)¶

# %% [markdown]
# ## SST data added in the end and correlation counted with other features

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Weather data

# %%
path1 = r"C:\Users\hp\Research-Try-ML\Weather-Antalya-2007-2023.csv"
df1 = pd.read_csv(path1)
df1
# Out:
#      2007            2007.1 2007.2 2007.3          2007.4 2007.5 2007.6  \
# 0    Time  Temperature (°F)    NaN    NaN  Dew Point (°F)    NaN    NaN
# 1     Jan               Max    Avg    Min             Max    Avg    Min
# 2       1                61   47.8     37              41   26.1      0
# 3       2                63   47.5     32              45   33.9      0
# 4       3                59   54.1     46              52   48.4     43
# ..    ...               ...    ...    ...             ...    ...    ...
# 383    27                63   50.7     43              46   42.1     37
# 384    28                64   52.7     43              39   28.1      0
# 385    29                59   49.8     43              27   20.3     16
# 386    30                61   46.5     37              36   21.4      0
# 387    31                63   46.2     36              37   23.9      0
#
#            2007.7 2007.8 2007.9           2007.10 2007.11 2007.12  \
# ...

# %% [markdown]
# ### have a look at all columns

# %%
pd.set_option("display.max_columns", None)
df1.head()
# Out:
#    2007            2007.1 2007.2 2007.3          2007.4 2007.5 2007.6  \
# 0  Time  Temperature (°F)    NaN    NaN  Dew Point (°F)    NaN    NaN
# 1   Jan               Max    Avg    Min             Max    Avg    Min
# 2     1                61   47.8     37              41   26.1      0
# 3     2                63   47.5     32              45   33.9      0
# 4     3                59   54.1     46              52   48.4     43
#
#          2007.7 2007.8 2007.9           2007.10 2007.11 2007.12  \
# 0  Humidity (%)    NaN    NaN  Wind Speed (mph)     NaN     NaN
# 1           Max    Avg    Min               Max     Avg     Min
# 2            87   48.2     22                15     8.4       2
# 3            87   62.6     29                 9     4.8       0
# 4            94   81.6     63                22      12       2
#
#          2007.13 2007.14 2007.15             2007.16  2008            2008.1  \
# 0  Pressure (in)     NaN     NaN  Precipitation (in)  Time  Temperature (°F)
# ...

# %% [markdown]
# # Will start with dropping useless features

# %% [markdown]
# ## Dataset includes Min Max values for each while our project targets only average data

# %%
drop_cols1 = ["2007.16", "2008.16", "2009.16", "2010.16", "2011.16", "2012.16", "2013.16", "2014.16"]

df1 = df1.drop(columns=drop_cols1)

# %% [markdown]
# ## Will rename the columns first so it's more clear what we drop and what we keep

# %%
df1.rename(columns={"2007.1": "MaxTemp2007", "2007.2": "AvgTemp2007", "2007.3": "MinTemp2007", "2007.4": "MaxDewPoint2007", "2007.5": "AvgDewPoint2007", "2007.6": "MinDewPoint2007", "2007.7": "MaxHumidi2007", "2007.8": "AvgHumidi2007", "2007.9": "MinHumidi2007", "2007.10": "MaxWind2007", "2007.11": "AvgWind2007", "2007.12": "MinWind2007", "2007.13": "MaxPress2007", "2007.14": "AvgPress2007", "2007.15": "MinPress2007"}, inplace=True)

# %%
df1.rename(columns={"2008.1": "MaxTemp2008", "2008.2": "AvgTemp2008", "2008.3": "MinTemp2008", "2008.4": "MaxDewPoint2008", "2008.5": "AvgDewPoint2008", "2008.6": "MinDewPoint2008", "2008.7": "MaxHumidi2008", "2008.8": "AvgHumidi2008", "2008.9": "MinHumidi2008", "2008.10": "MaxWind2008", "2008.11": "AvgWind2008", "2008.12": "MinWind2007", "2008.13": "MaxPress2008", "2008.14": "AvgPress2008", "2008.15": "MinPress2008"}, inplace=True)

df1.rename(columns={"2009.1": "MaxTemp2009", "2009.2": "AvgTemp2009", "2009.3": "MinTemp2009", "2009.4": "MaxDewPoint2009", "2009.5": "AvgDewPoint2009", "2009.6": "MinDewPoint2009", "2009.7": "MaxHumidi2009", "2009.8": "AvgHumidi2009", "2009.9": "MinHumidi2009", "2009.10": "MaxWind2009", "2009.11": "AvgWind2009", "2009.12": "MinWind2009", "2009.13": "MaxPress2009", "2009.14": "AvgPress2009", "2009.15": "MinPress2009"}, inplace=True)

df1.rename(columns={"2010.1": "MaxTemp2010", "2010.2": "AvgTemp2010", "2010.3": "MinTemp2010", "2010.4": "MaxDewPoint2010", "2010.5": "AvgDewPoint2010", "2010.6": "MinDewPoint2010", "2010.7": "MaxHumidi2010", "2010.8": "AvgHumidi2010", "2010.9": "MinHumidi2010", "2010.10": "MaxWind2010", "2010.11": "AvgWind2010", "2010.12": "MinWind2010", "2010.13": "MaxPress2010", "2010.14": "AvgPress2010", "2010.15": "MinPress2010"}, inplace=True)

df1.rename(columns={"2011.1": "MaxTemp2011", "2011.2": "AvgTemp2011", "2011.3": "MinTemp2011", "2011.4": "MaxDewPoint2011", "2011.5": "AvgDewPoint2011", "2011.6": "MinDewPoint2011", "2011.7": "MaxHumidi2011", "2011.8": "AvgHumidi2011", "2011.9": "MinHumidi2011", "2011.10": "MaxWind2011", "2011.11": "AvgWind2011", "2011.12": "MinWind2011", "2011.13": "MaxPress2011", "2011.14": "AvgPress2011", "2011.15": "MinPress2011"}, inplace=True)

df1.rename(columns={"2012.1": "MaxTemp2012", "2012.2": "AvgTemp2012", "2012.3": "MinTemp2012", "2012.4": "MaxDewPoint2012", "2012.5": "AvgDewPoint2012", "2012.6": "MinDewPoint2012", "2012.7": "MaxHumidi2012", "2012.8": "AvgHumidi2012", "2012.9": "MinHumidi2012", "2012.10": "MaxWind2012", "2012.11": "AvgWind2012", "2012.12": "MinWind2012", "2012.13": "MaxPress2012", "2012.14": "AvgPress2012", "2012.15": "MinPress2012"}, inplace=True)

df1.rename(columns={"2013.1": "MaxTemp2013", "2013.2": "AvgTemp2013", "2013.3": "MinTemp2013", "2013.4": "MaxDewPoint2013", "2013.5": "AvgDewPoint2013", "2013.6": "MinDewPoint2013", "2013.7": "MaxHumidi2013", "2013.8": "AvgHumidi2013", "2013.9": "MinHumidi2013", "2013.10": "MaxWind2013", "2013.11": "AvgWind2013", "2013.12": "MinWind2013", "2013.13": "MaxPress2013", "2013.14": "AvgPress2013", "2013.15": "MinPress2013"}, inplace=True)

df1.rename(columns={"2014.1": "MaxTemp2014", "2014.2": "AvgTemp2014", "2014.3": "MinTemp2014", "2014.4": "MaxDewPoint2014", "2014.5": "AvgDewPoint2014", "2014.6": "MinDewPoint2014", "2014.7": "MaxHumidi2014", "2014.8": "AvgHumidi2014", "2014.9": "MinHumidi2014", "2014.10": "MaxWind2014", "2014.11": "AvgWind2014", "2014.12": "MinWind2014", "2014.13": "MaxPress2014", "2014.14": "AvgPress2014", "2014.15": "MinPress2014"}, inplace=True)

df1.head()
# Out:
#    2007       MaxTemp2007 AvgTemp2007 MinTemp2007 MaxDewPoint2007  \
# 0  Time  Temperature (°F)         NaN         NaN  Dew Point (°F)
# 1   Jan               Max         Avg         Min             Max
# 2     1                61        47.8          37              41
# 3     2                63        47.5          32              45
# 4     3                59        54.1          46              52
#
#   AvgDewPoint2007 MinDewPoint2007 MaxHumidi2007 AvgHumidi2007 MinHumidi2007  \
# 0             NaN             NaN  Humidity (%)           NaN           NaN
# 1             Avg             Min           Max           Avg           Min
# 2            26.1               0            87          48.2            22
# 3            33.9               0            87          62.6            29
# 4            48.4              43            94          81.6            63
#
#         MaxWind2007 AvgWind2007 MinWind2007   MaxPress2007 AvgPress2007  \
# ...

# %% [markdown]
# ## Now we can go ahead with dropping and keeping the features as it is more clear what eah feature belongs to

# %% [markdown]
# ### drop the observation of index 1

# %%
df1.drop(1, inplace=True)
df1.head()
# Out:
#    2007       MaxTemp2007 AvgTemp2007 MinTemp2007 MaxDewPoint2007  \
# 0  Time  Temperature (°F)         NaN         NaN  Dew Point (°F)
# 2     1                61        47.8          37              41
# 3     2                63        47.5          32              45
# 4     3                59        54.1          46              52
# 5     4                59        51.8          45              52
#
#   AvgDewPoint2007 MinDewPoint2007 MaxHumidi2007 AvgHumidi2007 MinHumidi2007  \
# 0             NaN             NaN  Humidity (%)           NaN           NaN
# 2            26.1               0            87          48.2            22
# 3            33.9               0            87          62.6            29
# 4            48.4              43            94          81.6            63
# 5            47.2              41            94          85.1            63
#
#         MaxWind2007 AvgWind2007 MinWind2007   MaxPress2007 AvgPress2007  \
# ...

# %% [markdown]
# ## drop the observation of index 0

# %%
df1.drop(0, inplace=True)

# %% [markdown]
# ## Will keep the avg values in df2 which is our useful features

# %%
df2 = df1[["2007", "AvgTemp2007", "AvgDewPoint2007", "AvgHumidi2007", "AvgWind2007", "AvgPress2007", 
"AvgTemp2008", "AvgDewPoint2008", "AvgHumidi2008", "AvgWind2008", "AvgPress2008",
"AvgTemp2009", "AvgDewPoint2009", "AvgHumidi2009", "AvgWind2009", "AvgPress2009",
"AvgTemp2010", "AvgDewPoint2010", "AvgHumidi2010", "AvgWind2010", "AvgPress2010",
"AvgTemp2011", "AvgDewPoint2011", "AvgHumidi2011", "AvgWind2011", "AvgPress2011",
"AvgTemp2012", "AvgDewPoint2012", "AvgHumidi2012", "AvgWind2012", "AvgPress2012",
"AvgTemp2013", "AvgDewPoint2013", "AvgHumidi2013", "AvgWind2013", "AvgPress2013",
"AvgTemp2014", "AvgDewPoint2014", "AvgHumidi2014", "AvgWind2014", "AvgPress2014"]]

# %%
df2.rename(columns = {"2007": "Date"}, inplace=True)
df2.head()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2920\1960269192.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.rename(columns = {"2007": "Date"}, inplace=True)
#   Date AvgTemp2007 AvgDewPoint2007 AvgHumidi2007 AvgWind2007 AvgPress2007  \
# 2    1        47.8            26.1          48.2         8.4         30.2
# 3    2        47.5            33.9          62.6         4.8         30.2
# 4    3        54.1            48.4          81.6          12           30
# 5    4        51.8            47.2          85.1        12.8         29.8
# 6    5        46.9              40          77.9         9.6         29.7
#
#   AvgTemp2008 AvgDewPoint2008 AvgHumidi2008 AvgWind2008 AvgPress2008  \
# 2          51            35.3          62.4         6.1         29.8
# ...

# %% [markdown]
# ## in case we need to look at the full data use set_option and then reset_option after.

# %%
#pd.set_option("display.max_rows", None)

# %%
#pd.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Drop unnecessary observations then reset the index

# %%
df2.drop([31, 61, 94, 126, 159, 191, 224, 257, 321, 353], inplace=True)
df2.reset_index(drop=True, inplace=True)
df2
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2920\226821717.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop([31, 61, 94, 126, 159, 191, 224, 257, 321, 353], inplace=True)
#     Date AvgTemp2007 AvgDewPoint2007 AvgHumidi2007 AvgWind2007 AvgPress2007  \
# 0      1        47.8            26.1          48.2         8.4         30.2
# 1      2        47.5            33.9          62.6         4.8         30.2
# 2      3        54.1            48.4          81.6          12           30
# 3      4        51.8            47.2          85.1        12.8         29.8
# 4      5        46.9              40          77.9         9.6         29.7
# ..   ...         ...             ...           ...         ...          ...
# ...

# %% [markdown]
# ## Will add the month and year to Date feature

# %%
# we need to divide the date to add the month and year to it. 
df2.loc[:30, "Date"] = df2.loc[:30, "Date"].astype(str) + "-jan-"
df2.loc[32:59, "Date"] = df2.loc[32:59, "Date"].astype(str) + "-feb-"

#Now df2["Date"] contains the modified values
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2920\3659652076.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.loc[:30, "Date"] = df2.loc[:30, "Date"].astype(str) + "-jan-"
# C:\Users\hp\AppData\Local\Temp\ipykernel_2920\3659652076.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.loc[32:59, "Date"] = df2.loc[32:59, "Date"].astype(str) + "-feb-"

# %%
df2.loc[61:91, "Date"] = df2.loc[61:91, "Date"].astype(str) + "-mar-"
df2.loc[93:122, "Date"] = df2.loc[93:122, "Date"].astype(str) + "-apr-"
df2.loc[124:154, "Date"] = df2.loc[124:154, "Date"].astype(str) + "-may-"
df2.loc[156:185, "Date"] = df2.loc[156:185, "Date"].astype(str) + "-jun-"
df2.loc[187:217, "Date"] = df2.loc[187:217, "Date"].astype(str) + "-jul-"
df2.loc[219:249, "Date"] = df2.loc[219:249, "Date"].astype(str) + "-aug-"
df2.loc[251:280, "Date"] = df2.loc[251:280, "Date"].astype(str) + "-sep-"
df2.loc[282:312, "Date"] = df2.loc[282:312, "Date"].astype(str) + "-oct-"
df2.loc[314:343, "Date"] = df2.loc[314:343, "Date"].astype(str) + "-nov-"
df2.loc[345:375, "Date"] = df2.loc[345:375, "Date"].astype(str) + "-dec-"
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2920\1739874795.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.loc[61:91, "Date"] = df2.loc[61:91, "Date"].astype(str) + "-mar-"
# C:\Users\hp\AppData\Local\Temp\ipykernel_2920\1739874795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.loc[93:122, "Date"] = df2.loc[93:122, "Date"].astype(str) + "-apr-"
# C:\Users\hp\AppData\Local\Temp\ipykernel_2920\1739874795.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# # Deleting the additional observations exist and reset the index

# %%
# now delete the additional months observation.
df2.drop([31, 60, 92, 123, 155, 186, 218, 250, 281, 313, 344], inplace=True)
df2.reset_index(drop=True, inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2920\2273630743.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop([31, 60, 92, 123, 155, 186, 218, 250, 281, 313, 344], inplace=True)

# %%
# data was saved here as csv file

# %%
path = r"C:\Users\hp\Research-Try-ML\Antalya-2007-2023-weather-full.csv"
df_full = pd.read_csv(path)
df_full
# Out:
#         Date  AvgTemp2007  AvgDewPoint2007  AvgHumidi2007  AvgWind2007  \
# 0     1-jan-         47.8             26.1           48.2          8.4
# 1     2-jan-         47.5             33.9           62.6          4.8
# 2     3-jan-         54.1             48.4           81.6         12.0
# 3     4-jan-         51.8             47.2           85.1         12.8
# 4     5-jan-         46.9             40.0           77.9          9.6
# ..       ...          ...              ...            ...          ...
# 360  27-dec-         50.7             42.1           73.6          5.4
# 361  28-dec-         52.7             28.1           50.7         11.1
# 362  29-dec-         49.8             20.3           32.0         13.6
# 363  30-dec-         46.5             21.4           41.9          7.3
# 364  31-dec-         46.2             23.9           56.3          5.6
#
#      AvgPress2007  AvgTemp2008  AvgDewPoint2008  AvgHumidi2008  AvgWind2008  \
# ...

# %% [markdown]
# # Drop the useless features

# %%
drop_cols2 = ["2015", "2015.1", "2015.3", "2015.4", "2015.6", "2015.7", "2015.9", "2015.10", "2015.12", "2015.13", "2015.15", "2015.16",
              "2016", "2016.1", "2016.3", "2016.4", "2016.6", "2016.7", "2016.9", "2016.10", "2016.12", "2016.13", "2016.15", "2016.16",
              "2017", "2017.1", "2017.3", "2017.4", "2017.6", "2017.7", "2017.9", "2017.10", "2017.12", "2017.13", "2017.15", "2017.16",
              "2018", "2018.1", "2018.3", "2018.4", "2018.6", "2018.7", "2018.9", "2018.10", "2018.12", "2018.13", "2018.15", "2018.16",
              "2019", "2019.1", "2019.3", "2019.4", "2019.6", "2019.7", "2019.9", "2019.10", "2019.12", "2019.13", "2019.15", "2019.16",
              "2020", "2020.1", "2020.3", "2020.4", "2020.6", "2020.7", "2020.9", "2020.10", "2020.12", "2020.13", "2020.15", "2020.16",
              "2021", "2021.1", "2021.3", "2021.4", "2021.6", "2021.7", "2021.9", "2021.10", "2021.12", "2021.13", "2021.15", "2021.16",
              "2022", "2022.1", "2022.3", "2022.4", "2022.6", "2022.7", "2022.9", "2022.10", "2022.12", "2022.13", "2022.15", "2022.16",
              "2023", "2023.1", "2023.3", "2023.4", "2023.6", "2023.7", "2023.9", "2023.10", "2023.12", "2023.13", "2023.15", "2023.16",]

df_full = df_full.drop(columns=drop_cols2)

# %% [markdown]
# # Rename the columns with appropriate names

# %%
df_full.rename(columns={"2015.2": "AvgTemp2015", "2015.5": "AvgDewPoint2015", "2015.8": "AvgHumidi2015", "2015.11": "AvgWind2015", "2015.14": "AvgPress2015", 
                       "2016.2": "AvgTemp2016", "2016.5": "AvgDewPoint2016", "2016.8": "AvgHumidi2016", "2016.11": "AvgWind2016", "2016.14": "AvgPress2016",
                       "2017.2": "AvgTemp2017", "2017.5": "AvgDewPoint2017", "2017.8": "AvgHumidi2017", "2017.11": "AvgWind2017", "2017.14": "AvgPress2017",
                       "2018.2": "AvgTemp2018", "2018.5": "AvgDewPoint2018", "2018.8": "AvgHumidi2018", "2018.11": "AvgWind2018", "2018.14": "AvgPress2018",
                       "2019.2": "AvgTemp2019", "2019.5": "AvgDewPoint2019", "2019.8": "AvgHumidi2019", "2019.11": "AvgWind2019", "2019.14": "AvgPress2019",
                       "2020.2": "AvgTemp2020", "2020.5": "AvgDewPoint2020", "2020.8": "AvgHumidi2020", "2020.11": "AvgWind2020", "2020.14": "AvgPress2020",
                       "2021.2": "AvgTemp2021", "2021.5": "AvgDewPoint2021", "2021.8": "AvgHumidi2021", "2021.11": "AvgWind2021", "2021.14": "AvgPress2021",
                       "2022.2": "AvgTemp2022", "2022.5": "AvgDewPoint2022", "2022.8": "AvgHumidi2022", "2022.11": "AvgWind2022", "2022.14": "AvgPress2022",
                       "2023.2": "AvgTemp2023", "2023.5": "AvgDewPoint2023", "2023.8": "AvgHumidi2023", "2023.11": "AvgWind2023", "2023.14": "AvgPress2023"}, inplace=True)
df_full
# Out:
#         Date  AvgTemp2007  AvgDewPoint2007  AvgHumidi2007  AvgWind2007  \
# 0     1-jan-         47.8             26.1           48.2          8.4
# 1     2-jan-         47.5             33.9           62.6          4.8
# 2     3-jan-         54.1             48.4           81.6         12.0
# 3     4-jan-         51.8             47.2           85.1         12.8
# 4     5-jan-         46.9             40.0           77.9          9.6
# ..       ...          ...              ...            ...          ...
# 360  27-dec-         50.7             42.1           73.6          5.4
# 361  28-dec-         52.7             28.1           50.7         11.1
# 362  29-dec-         49.8             20.3           32.0         13.6
# 363  30-dec-         46.5             21.4           41.9          7.3
# 364  31-dec-         46.2             23.9           56.3          5.6
#
#      AvgPress2007  AvgTemp2008  AvgDewPoint2008  AvgHumidi2008  AvgWind2008  \
# ...

# %% [markdown]
# ## drop useless features

# %%
drop_cols3 = ["Unnamed: 41", "Unnamed: 59", "Unnamed: 77", "Unnamed: 95", "Unnamed: 113", "Unnamed: 131", "Unnamed: 149", "Unnamed: 167"]

df_full = df_full.drop(columns=drop_cols3)

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 86 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             365 non-null    object
#  1   AvgTemp2007      365 non-null    float64
#  2   AvgDewPoint2007  365 non-null    float64
#  3   AvgHumidi2007    365 non-null    float64
#  4   AvgWind2007      365 non-null    float64
#  5   AvgPress2007     365 non-null    float64
#  6   AvgTemp2008      365 non-null    float64
#  7   AvgDewPoint2008  365 non-null    float64
#  8   AvgHumidi2008    365 non-null    float64
#  9   AvgWind2008      365 non-null    float64
#  10  AvgPress2008     365 non-null    float64
#  11  AvgTemp2009      365 non-null    float64
#  12  AvgDewPoint2009  365 non-null    float64
#  13  AvgHumidi2009    365 non-null    float64
#  14  AvgWind2009      365 non-null    float64
#  15  AvgPress2009     365 non-null    float64
# ...

# %% [markdown]
# # Covert to engineering units
# ## Tempreature from Fahrenheit to Celsius

# %%
#now we will convert Avg Temp to celsius
df_full["AvgTemp2007"] = (df_full["AvgTemp2007"] - 32) / 1.8 
df_full["AvgTemp2008"] = (df_full["AvgTemp2008"] - 32) / 1.8 
df_full["AvgTemp2009"] = (df_full["AvgTemp2009"] - 32) / 1.8 
df_full["AvgTemp2010"] = (df_full["AvgTemp2010"] - 32) / 1.8 
df_full["AvgTemp2011"] = (df_full["AvgTemp2011"] - 32) / 1.8 
df_full["AvgTemp2012"] = (df_full["AvgTemp2012"] - 32) / 1.8 
df_full["AvgTemp2013"] = (df_full["AvgTemp2013"] - 32) / 1.8 
df_full["AvgTemp2014"] = (df_full["AvgTemp2014"] - 32) / 1.8 
df_full["AvgTemp2015"] = (df_full["AvgTemp2015"] - 32) / 1.8 
df_full["AvgTemp2016"] = (df_full["AvgTemp2016"] - 32) / 1.8 
df_full["AvgTemp2017"] = (df_full["AvgTemp2017"] - 32) / 1.8 
df_full["AvgTemp2018"] = (df_full["AvgTemp2018"] - 32) / 1.8 
df_full["AvgTemp2019"] = (df_full["AvgTemp2019"] - 32) / 1.8 
df_full["AvgTemp2020"] = (df_full["AvgTemp2020"] - 32) / 1.8 
df_full["AvgTemp2021"] = (df_full["AvgTemp2021"] - 32) / 1.8
df_full["AvgTemp2022"] = (df_full["AvgTemp2022"] - 32) / 1.8 
df_full["AvgTemp2023"] = (df_full["AvgTemp2023"] - 32) / 1.8

# %% [markdown]
# ## Dew point from Fahrenheit to Celsius

# %%
#now we will convert AvgDewPoint to celsius
df_full["AvgDewPoint2007"] = (df_full["AvgDewPoint2007"] - 32) / 1.8 
df_full["AvgDewPoint2008"] = (df_full["AvgDewPoint2008"] - 32) / 1.8 
df_full["AvgDewPoint2009"] = (df_full["AvgDewPoint2009"] - 32) / 1.8 
df_full["AvgDewPoint2010"] = (df_full["AvgDewPoint2010"] - 32) / 1.8 
df_full["AvgDewPoint2011"] = (df_full["AvgDewPoint2011"] - 32) / 1.8 
df_full["AvgDewPoint2012"] = (df_full["AvgDewPoint2012"] - 32) / 1.8 
df_full["AvgDewPoint2013"] = (df_full["AvgDewPoint2013"] - 32) / 1.8 
df_full["AvgDewPoint2014"] = (df_full["AvgDewPoint2014"] - 32) / 1.8 
df_full["AvgDewPoint2015"] = (df_full["AvgDewPoint2015"] - 32) / 1.8 
df_full["AvgDewPoint2016"] = (df_full["AvgDewPoint2016"] - 32) / 1.8 
df_full["AvgDewPoint2017"] = (df_full["AvgDewPoint2017"] - 32) / 1.8 
df_full["AvgDewPoint2018"] = (df_full["AvgDewPoint2018"] - 32) / 1.8 
df_full["AvgDewPoint2019"] = (df_full["AvgDewPoint2019"] - 32) / 1.8 
df_full["AvgDewPoint2020"] = (df_full["AvgDewPoint2020"] - 32) / 1.8 
df_full["AvgDewPoint2021"] = (df_full["AvgDewPoint2021"] - 32) / 1.8
df_full["AvgDewPoint2022"] = (df_full["AvgDewPoint2022"] - 32) / 1.8 
df_full["AvgDewPoint2023"] = (df_full["AvgDewPoint2023"] - 32) / 1.8

# %% [markdown]
# ## Wind Speed from mph to mps

# %%
#now will change the Wind speed from mph to mps  divide by 2.237
df_full["AvgWind2007"] = df_full["AvgWind2007"] / 2.237 
df_full["AvgWind2008"] = df_full["AvgWind2008"] / 2.237
df_full["AvgWind2009"] = df_full["AvgWind2009"] / 2.237 
df_full["AvgWind2010"] = df_full["AvgWind2010"] / 2.237 
df_full["AvgWind2011"] = df_full["AvgWind2011"] / 2.237 
df_full["AvgWind2012"] = df_full["AvgWind2012"] / 2.237 
df_full["AvgWind2013"] = df_full["AvgWind2013"] / 2.237 
df_full["AvgWind2014"] = df_full["AvgWind2014"] / 2.237
df_full["AvgWind2015"] = df_full["AvgWind2015"] / 2.237 
df_full["AvgWind2016"] = df_full["AvgWind2016"] / 2.237 
df_full["AvgWind2017"] = df_full["AvgWind2017"] / 2.237 
df_full["AvgWind2018"] = df_full["AvgWind2018"] / 2.237
df_full["AvgWind2019"] = df_full["AvgWind2019"] / 2.237
df_full["AvgWind2020"] = df_full["AvgWind2020"] / 2.237 
df_full["AvgWind2021"] = df_full["AvgWind2021"] / 2.237
df_full["AvgWind2022"] = df_full["AvgWind2022"] / 2.237
df_full["AvgWind2023"] = df_full["AvgWind2023"] / 2.237

# %% [markdown]
# ## Pressure from (in) "inches of mercury" to Pascal

# %%
#now will change the Pressure unit from in "inches of mercury" to Pa or Pascal (* 3386.39  )
df_full["AvgPress2007"] = df_full["AvgPress2007"] * 3386.39 
df_full["AvgPress2008"] = df_full["AvgPress2008"] * 3386.39
df_full["AvgPress2009"] = df_full["AvgPress2009"] * 3386.39
df_full["AvgPress2010"] = df_full["AvgPress2010"] * 3386.39 
df_full["AvgPress2011"] = df_full["AvgPress2011"] * 3386.39
df_full["AvgPress2012"] = df_full["AvgPress2012"] * 3386.39 
df_full["AvgPress2013"] = df_full["AvgPress2013"] * 3386.39
df_full["AvgPress2014"] = df_full["AvgPress2014"] * 3386.39
df_full["AvgPress2015"] = df_full["AvgPress2015"] * 3386.39 
df_full["AvgPress2016"] = df_full["AvgPress2016"] * 3386.39 
df_full["AvgPress2017"] = df_full["AvgPress2017"] * 3386.39 
df_full["AvgPress2018"] = df_full["AvgPress2018"] * 3386.39
df_full["AvgPress2019"] = df_full["AvgPress2019"] * 3386.39
df_full["AvgPress2020"] = df_full["AvgPress2020"] * 3386.39
df_full["AvgPress2021"] = df_full["AvgPress2021"] * 3386.39
df_full["AvgPress2022"] = df_full["AvgPress2022"] * 3386.39
df_full["AvgPress2023"] = df_full["AvgPress2023"] * 3386.39

# %%
df_full
# Out:
#         Date  AvgTemp2007  AvgDewPoint2007  AvgHumidi2007  AvgWind2007  \
# 0     1-jan-     8.777778        -3.277778           48.2     3.755029
# 1     2-jan-     8.611111         1.055556           62.6     2.145731
# 2     3-jan-    12.277778         9.111111           81.6     5.364327
# 3     4-jan-    11.000000         8.444444           85.1     5.721949
# 4     5-jan-     8.277778         4.444444           77.9     4.291462
# ..       ...          ...              ...            ...          ...
# 360  27-dec-    10.388889         5.611111           73.6     2.413947
# 361  28-dec-    11.500000        -2.166667           50.7     4.962003
# 362  29-dec-     9.888889        -6.500000           32.0     6.079571
# 363  30-dec-     8.055556        -5.888889           41.9     3.263299
# 364  31-dec-     7.888889        -4.500000           56.3     2.503353
#
#      AvgPress2007  AvgTemp2008  AvgDewPoint2008  AvgHumidi2008  AvgWind2008  \
# ...

# %% [markdown]
# # Now will load the SST and then merge it with the weather data

# %%
path5 = r"C:\Users\hp\Desktop\Apply\sst-stat.csv"
df_sst = pd.read_csv(path5, usecols=["2007", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "2021", "2022", "2023"])
df_sst
# Out:
#      2007  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018  \
# 0    17.9  18.5  19.6  19.0  19.6  18.1  18.3  17.8  19.0  18.2  17.9  19.3
# 1    17.9  18.3  19.5  19.1  19.4  18.1  18.8  17.7  18.9  18.0  17.8  19.2
# 2    17.7  18.7  19.2  19.1  19.1  18.1  18.8  17.7  18.8  17.9  17.7  19.1
# 3    17.5  19.1  19.0  18.9  19.0  17.9  18.7  17.7  18.6  17.8  17.7  19.2
# 4    17.4  18.8  18.8  19.0  19.0  17.9  18.7  17.7  18.4  18.1  17.7  19.2
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 360  19.2  19.1  19.2  19.6  18.5  18.8  17.8  19.5  19.2  18.4  19.6  19.5
# 361  19.1  19.2  19.3  19.4  18.3  18.8  17.7  19.6  19.1  18.2  19.4  19.4
# 362  18.9  19.2  19.3  19.3  18.2  18.8  18.1  19.6  19.2  18.1  19.3  19.2
# 363  18.7  19.2  19.5  19.4  18.2  18.8  18.0  19.5  19.1  18.0  19.3  19.1
# 364  18.6  20.1  19.2  19.5  18.2  18.6  17.9  19.2  18.7  18.0  19.3  19.0
#
#      2019  2020  2021  2022  2023
# ...

# %% [markdown]
# ## Rename the features in df_sst

# %%
df_sst.rename(columns={"2007": "SST2007", "2008": "SST2008", "2009": "SST2009", "2010": "SST2010", "2011": "SST2011", 
                       "2012": "SST2012", "2013": "SST2013", "2014": "SST2014", "2015": "SST2015", "2016": "SST2016",
                       "2017": "SST2017", "2018": "SST2018", "2019": "SST2019", "2020": "SST2020", "2021": "SST2021",
                       "2022": "SST2022", "2023": "SST2023"}, inplace=True)

# %% [markdown]
# ## shape of each data file

# %%
print("weather data file shape is:", df_full.shape)
print("sst data file shape is:", df_sst.shape)
# Out:
# weather data file shape is: (365, 86)
# sst data file shape is: (365, 17)

# %% [markdown]
# # Let's merge both data files together

# %%
#now let's merge all the data together
df_concat2 = pd.concat([df_full, df_sst], ignore_index=True)

# Reset the index to start from 0
df_concat2.reset_index(drop=True, inplace=True)

df_concat2
# Out:
#        Date  AvgTemp2007  AvgDewPoint2007  AvgHumidi2007  AvgWind2007  \
# 0    1-jan-     8.777778        -3.277778           48.2     3.755029
# 1    2-jan-     8.611111         1.055556           62.6     2.145731
# 2    3-jan-    12.277778         9.111111           81.6     5.364327
# 3    4-jan-    11.000000         8.444444           85.1     5.721949
# 4    5-jan-     8.277778         4.444444           77.9     4.291462
# ..      ...          ...              ...            ...          ...
# 725     NaN          NaN              NaN            NaN          NaN
# 726     NaN          NaN              NaN            NaN          NaN
# 727     NaN          NaN              NaN            NaN          NaN
# 728     NaN          NaN              NaN            NaN          NaN
# 729     NaN          NaN              NaN            NaN          NaN
#
#      AvgPress2007  AvgTemp2008  AvgDewPoint2008  AvgHumidi2008  AvgWind2008  \
# ...

# %%
df_concat2.to_csv(r"C:\Users\hp\Desktop\Apply\Antaly-All.csv")

# %%
path7 = (r"C:\Users\hp\Desktop\Apply\Antaly-All.csv")
df_all = pd.read_csv(path7)
df_all
# Out:
#      Unnamed: 0    Date  AvgTemp2007  AvgDewPoint2007  AvgHumidi2007  \
# 0             0  1-jan-     8.777778        -3.277778           48.2
# 1             1  2-jan-     8.611111         1.055556           62.6
# 2             2  3-jan-    12.277778         9.111111           81.6
# 3             3  4-jan-    11.000000         8.444444           85.1
# 4             4  5-jan-     8.277778         4.444444           77.9
# ..          ...     ...          ...              ...            ...
# 725         725     NaN          NaN              NaN            NaN
# 726         726     NaN          NaN              NaN            NaN
# 727         727     NaN          NaN              NaN            NaN
# 728         728     NaN          NaN              NaN            NaN
# 729         729     NaN          NaN              NaN            NaN
#
#      AvgWind2007  AvgPress2007  AvgTemp2008  AvgDewPoint2008  AvgHumidi2008  \
# ...

# %% [markdown]
# ## Note: here Unnamed: 0 was tghe index as I saved with forgeting to drop the index (index=False)

# %%
df_all = df_all.drop("Unnamed: 0", axis="columns")

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Columns: 103 entries, Date to SST2023
# dtypes: float64(102), object(1)
# memory usage: 587.6+ KB

# %% [markdown]
# ## description of the datafile

# %%
df_all.describe()
# Out:
#        AvgTemp2007  AvgDewPoint2007  AvgHumidi2007  AvgWind2007  AvgPress2007  \
# count   365.000000       365.000000     365.000000   365.000000     365.00000
# mean     19.423744         8.983409      57.836712     3.342907  100638.87191
# std       7.659842         7.630810      16.627437     1.507807     669.63680
# min       5.611111        -7.833333      15.200000     1.564595   96173.47600
# 25%      12.888889         3.833333      45.700000     2.324542  100237.14400
# 50%      19.166667         8.833333      61.700000     2.771569  100575.78300
# 75%      25.777778        15.055556      70.300000     3.889137  100914.42200
# max      36.611111        24.722222      89.500000     9.924005  102268.97800
#
#        AvgTemp2008  AvgDewPoint2008  AvgHumidi2008  AvgWind2008  \
# count   365.000000       365.000000     365.000000   365.000000
# mean     19.456012         9.155099      56.980548     3.276771
# std       7.707132         7.990217      14.959713     1.605180
# ...

# %% [markdown]
# ## Save the file

# %%
df_all.to_csv(r"C:\Users\hp\Research-Try-ML\Antalya-All-Div2007-2023.csv", index=False)

# %% [markdown]
# # Statistics
# ## Now will assign a name for each feature and include df for it
# ### start with Tempereature

# %%
df_Temp = df_all.loc[:, ["AvgTemp2007", "AvgTemp2008", "AvgTemp2009", "AvgTemp2010", "AvgTemp2011", "AvgTemp2012", "AvgTemp2013", "AvgTemp2014", "AvgTemp2015", "AvgTemp2016", "AvgTemp2017", "AvgTemp2018", "AvgTemp2019", "AvgTemp2020", "AvgTemp2021", "AvgTemp2022", "AvgTemp2023"]]
df_Temp
# Out:
#      AvgTemp2007  AvgTemp2008  AvgTemp2009  AvgTemp2010  AvgTemp2011  \
# 0       8.777778    10.555556     5.111111    10.722222     8.888889
# 1       8.611111    10.333333     5.111111    14.500000     8.833333
# 2      12.277778    10.611111     7.833333    10.888889    10.777778
# 3      11.000000     9.166667    10.555556    10.777778    11.333333
# 4       8.277778     8.055556    12.000000    10.611111    11.000000
# ..           ...          ...          ...          ...          ...
# 725          NaN          NaN          NaN          NaN          NaN
# 726          NaN          NaN          NaN          NaN          NaN
# 727          NaN          NaN          NaN          NaN          NaN
# 728          NaN          NaN          NaN          NaN          NaN
# 729          NaN          NaN          NaN          NaN          NaN
#
#      AvgTemp2012  AvgTemp2013  AvgTemp2014  AvgTemp2015  AvgTemp2016  \
# ...

# %% [markdown]
# ## Histogram

# %%
df_Temp = df_Temp.dropna(axis=0)
df_Temp
# Out:
#      AvgTemp2007  AvgTemp2008  AvgTemp2009  AvgTemp2010  AvgTemp2011  \
# 0       8.777778    10.555556     5.111111    10.722222     8.888889
# 1       8.611111    10.333333     5.111111    14.500000     8.833333
# 2      12.277778    10.611111     7.833333    10.888889    10.777778
# 3      11.000000     9.166667    10.555556    10.777778    11.333333
# 4       8.277778     8.055556    12.000000    10.611111    11.000000
# ..           ...          ...          ...          ...          ...
# 360    10.388889     7.222222    14.222222    13.611111     7.833333
# 361    11.500000     8.222222    15.388889    13.500000     8.388889
# 362     9.888889     9.277778    15.222222    14.611111     8.055556
# 363     8.055556     7.055556    12.111111    12.722222     9.055556
# 364     7.888889     5.666667     9.777778    11.666667     9.555556
#
#      AvgTemp2012  AvgTemp2013  AvgTemp2014  AvgTemp2015  AvgTemp2016  \
# ...

# %%
plt.hist(df_Temp)
plt.xlabel("Temp in C")
plt.ylabel("Frequency")
plt.title("Histogram: Temp 2007-2023")
# Out:
# Text(0.5, 1.0, 'Histogram: Temp 2007-2023')

# %%
plt.boxplot(df_Temp)
plt.xlabel("1 is 2007 ----- 17 is 2023")
plt.ylabel("Temp in Celsius")
plt.title("Boxplot: Temp 2007-2023")
# Out:
# Text(0.5, 1.0, 'Boxplot: Temp 2007-2023')

# %% [markdown]
# ## Same process can be applied for all other features if needed

# %%
df_Dew = df_all.loc[:, ["Date", "AvgDewPoint2007", "AvgDewPoint2008", "AvgDewPoint2009", "AvgDewPoint2010", "AvgDewPoint2011", "AvgDewPoint2012", "AvgDewPoint2013", "AvgDewPoint2014", "AvgDewPoint2015", "AvgDewPoint2016", "AvgDewPoint2017", "AvgDewPoint2018", "AvgDewPoint2019", "AvgDewPoint2020", "AvgDewPoint2021", "AvgDewPoint2022", "AvgDewPoint2023"]]

# %%
df_SST = df_all.loc[:, ["SST2007", "SST2008", "SST2009", "SST2010", "SST2011", "SST2012", "SST2013", "SST2014", "SST2015", "SST2016", "SST2017", "SST2018", "SST2019", "SST2020", "SST2021", "SST2022", "SST2023"]]

# %%
df_SST.to_csv(r"C:\Users\hp\Desktop\Apply\SST2007-SST2023-1time.csv", index=False)

# %% [markdown]
# # Here will work with df_ant include all features on daily date as well as described below

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
path_Ant = r"C:\Users\hp\Research-Try-ML\Antalya1-Last-Cleaned-20072023.csv"
df_ant = pd.read_csv(path_Ant)
df_ant
# Out:
#            Date   Temp(°C)  DewPoint(°C)  Humidi(%)  WindSpeed(mps)  \
# 0      1-Jan-07   8.777778     -3.277778       48.2        3.755029
# 1      2-Jan-07   8.611111      1.055556       62.6        2.145731
# 2      3-Jan-07  12.277778      9.111111       81.6        5.364327
# 3      4-Jan-07  11.000000      8.444444       85.1        5.721949
# 4      5-Jan-07   8.277778      4.444444       77.9        4.291462
# ...         ...        ...           ...        ...             ...
# 6204  26-Dec-23  12.722222      7.500000       71.8        2.369245
# 6205  27-Dec-23  15.055556      7.833333       63.5        3.576218
# 6206  28-Dec-23  15.555556      6.333333       55.6        3.263299
# 6207  29-Dec-23  13.222222      7.444444       69.3        2.413947
# 6208  30-Dec-23  12.666667      8.833333       77.5        2.235136
#
#        Press(Pa)  SST(°C)
# 0     102268.978     17.9
# 1     102268.978     17.9
# 2     101591.700     17.7
# 3     100914.422     17.5
# ...

# %%
df_ant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6209 entries, 0 to 6208
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            6209 non-null   object
#  1   Temp(°C)        6209 non-null   float64
#  2   DewPoint(°C)    6209 non-null   float64
#  3   Humidi(%)       6209 non-null   float64
#  4   WindSpeed(mps)  6209 non-null   float64
#  5   Press(Pa)       6209 non-null   float64
#  6   SST(°C)         6209 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 339.7+ KB

# %% [markdown]
# # Statistical study

# %% [markdown]
# # Can apply Histograms... Boxplots....Barcharts for any needed feature
# ### Here are some examples:

# %%
df_ant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6209 entries, 0 to 6208
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            6209 non-null   object
#  1   Temp(°C)        6209 non-null   float64
#  2   DewPoint(°C)    6209 non-null   float64
#  3   Humidi(%)       6209 non-null   float64
#  4   WindSpeed(mps)  6209 non-null   float64
#  5   Press(Pa)       6209 non-null   float64
#  6   SST(°C)         6209 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 339.7+ KB

# %%
df_ant["DewPoint(°C)"].plot(kind="bar", title="Barchart: DewPoint(°C)", ylabel="in °C")
# Out:
# <Axes: title={'center': 'Barchart: DewPoint(°C)'}, ylabel='in °C'>

# %%
plt.boxplot(df_ant["WindSpeed(mps)"], vert=True)
plt.ylabel("in mps")
plt.title("Boxplot: WindSpeed(mps)")
# Out:
# Text(0.5, 1.0, 'Boxplot: WindSpeed(mps)')

# %%
plt.hist(df_ant["Press(Pa)"])
plt.xlabel("in Pa")
plt.ylabel("Frequeny")
plt.title("Histogram: Press(Pa)")
# Out:
# Text(0.5, 1.0, 'Histogram: Press(Pa)')

# %% [markdown]
# # Variance values for each feature

# %%
df_ant[["Temp(°C)", "DewPoint(°C)", "Humidi(%)", "WindSpeed(mps)", "Press(Pa)", "SST(°C)"]].var()
# Out:
# Temp(°C)           52.968788
# DewPoint(°C)       54.040792
# Humidi(%)         279.028374
# WindSpeed(mps)      2.223750
# Press(Pa)          39.608848
# SST(°C)            20.461511
# dtype: float64

# %% [markdown]
# # Correlation coefficient table between features

# %%
#the "Date" column converted to datetime
df_ant["Date"] = pd.to_datetime(df_ant["Date"])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12716\550545982.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_ant["Date"] = pd.to_datetime(df_ant["Date"])

# %%
print("Correlation Matrix of each Variable:")
df_ant.corr()
# Out:
# Correlation Matrix of each Variable:
#                     Date  Temp(°C)  DewPoint(°C)  Humidi(%)  WindSpeed(mps)  \
# Date            1.000000  0.050394      0.099036   0.050052        0.112627
# Temp(°C)        0.050394  1.000000      0.734512  -0.278665       -0.127926
# DewPoint(°C)    0.099036  0.734512      1.000000   0.429741       -0.486123
# Humidi(%)       0.050052 -0.278665      0.429741   1.000000       -0.522113
# WindSpeed(mps)  0.112627 -0.127926     -0.486123  -0.522113        1.000000
# Press(Pa)       0.033106 -0.605349     -0.523672   0.055207       -0.076113
# SST(°C)         0.079728  0.881641      0.672899  -0.223705       -0.136465
#
#                 Press(Pa)   SST(°C)
# Date             0.033106  0.079728
# Temp(°C)        -0.605349  0.881641
# DewPoint(°C)    -0.523672  0.672899
# Humidi(%)        0.055207 -0.223705
# WindSpeed(mps)  -0.076113 -0.136465
# Press(Pa)        1.000000 -0.492104
# SST(°C)         -0.492104  1.000000

# %% [markdown]
# ## Heatmap for the correlation values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
correlation_matrix = df_ant.corr()
# Create a heatmap with annotations
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5, cbar=True)
plt.title("Correlation Matrix Heatmap with Annotations")
plt.show()

# %% [markdown]
# ## Now will change the Pressure unit into hpa by dividing 100

# %%
df_ant["Press(Pa)"] = df_ant["Press(Pa)"] / 100

# %%
#df.to_csv(r"C:\Users\hp\Research-Try-ML\Antalya-20072023-CleanedData.csv", index=False)

# %%
path = r"C:\Users\hp\Research-Try-ML\Antalya-20072023-CleanedData.csv"
df1 = pd.read_csv(path)

# %% [markdown]
# ## With kindest Regards.
# ## Abdallah I. J. Dwikat
# ### email: adweikat12@gmail.com  /   linkedin: Abdallah Dwikat
