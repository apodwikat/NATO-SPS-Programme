# %%
from IPython.display import Image
img_path = r"C:\Users\hp\Pictures\Screenshots\Screenshot 2024-08-07 134548.png"
Image(filename=img_path, width=1000, height=1500)

# %% [markdown]
# # Sea Surface Temperature (SST) - NATO Science for Peace and Security (SPS) Programme

# %% [markdown]
# ## Abdallah I. J. Dwikat - Computer Engineering - Summer Intern at NATO (SPS) Programme

# %% [markdown]
# ### The goal from this directory is to have a clean dataset that will be used later on for differnet Machine Learning Models and also having a statistical study including different visualizations to find the trend of SST Temperature in Celsius with years. (The data collected on daily basis over 17 years between 2007 and 2023)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading the data

# %%
path = r"C:\Users\hp\Research-Try-ML\SST-Antalya-2007-2023.csv"
df = pd.read_csv(path)
df.head()
# Out:
#      Day    2007  No7     Min     Max  Day.1    2008     No8   Min.1   Max.1  \
# 0  1-Jan  17.9°C  NaN  17.8°C  19.6°C  1-Jan  18.5°C  18.5°C  17.8°C  19.6°C
# 1  2-Jan  17.9°C  NaN  17.7°C    20°C  2-Jan  18.3°C  18.3°C  17.7°C    20°C
# 2  3-Jan  17.7°C  NaN  17.7°C  19.9°C  3-Jan  18.7°C  18.7°C  17.7°C  19.9°C
# 3  4-Jan  17.5°C  NaN  17.5°C  19.6°C  4-Jan  19.1°C  19.1°C  17.5°C  19.6°C
# 4  5-Jan  17.4°C  NaN  17.4°C  19.5°C  5-Jan  18.8°C  18.8°C  17.4°C  19.5°C
#
#    ... Day.15    2022    No22  Min.15  Max.15 Day.16    2023    No23  Min.16  \
# 0  ...  1-Jan    19°C    19°C  17.8°C  19.6°C  1-Jan  19.7°C  19.7°C  17.8°C
# 1  ...  2-Jan  19.5°C  19.5°C  17.7°C    20°C  2-Jan  19.8°C  19.8°C  17.7°C
# 2  ...  3-Jan  19.2°C  19.2°C  17.7°C  19.9°C  3-Jan  19.8°C  19.8°C  17.7°C
# 3  ...  4-Jan  19.3°C  19.3°C  17.5°C  19.6°C  4-Jan  19.7°C  19.7°C  17.5°C
# 4  ...  5-Jan  19.2°C  19.2°C  17.4°C  19.5°C  5-Jan  19.7°C  19.7°C  17.4°C
#
#    Max.16
# 0  19.6°C
# 1    20°C
# ...

# %% [markdown]
# # First step to drop unnecessary features/observations

# %% [markdown]
# ## will start with features first and then will move to observations

# %% [markdown]
# ### Here dropped some fgeatures which were duplicated features.

# %%
drop_cols = ["No7", "No8", "No9", "No10", "No11", "No12", "No13", "No14", "No15", "No16", "No17", "No18", "No19", "No20", "No21", "No22", "No23"]
df = df.drop(columns=drop_cols)

# %% [markdown]
# ### the max and min values will be dropped as we deal with average

# %%
drop_cols1 = ["Min", "Max", "Min.1", "Max.1", "Min.2", "Max.2", "Min.3", "Max.3", "Min.4", "Max.4",	"Min.5", "Max.5", "Min.6", 	"Max.6", "Min.7", "Max.7", "Min.8", "Max.8", "Min.9", "Max.9", "Min.10", "Max.10", "Min.11", "Max.11", "Min.12", "Max.12", "Min.13", "Max.13", "Min.14", "Max.14", "Min.15", "Max.15", "Min.16", "Max.16"]	
df = df.drop(columns=drop_cols1)

# %%
df.head()
# Out:
#      Day    2007  Day.1    2008  Day.2    2009  Day.3    2010  Day.4    2011  \
# 0  1-Jan  17.9°C  1-Jan  18.5°C  1-Jan  19.6°C  1-Jan    19°C  1-Jan  19.6°C
# 1  2-Jan  17.9°C  2-Jan  18.3°C  2-Jan  19.5°C  2-Jan  19.1°C  2-Jan  19.4°C
# 2  3-Jan  17.7°C  3-Jan  18.7°C  3-Jan  19.2°C  3-Jan  19.1°C  3-Jan  19.1°C
# 3  4-Jan  17.5°C  4-Jan  19.1°C  4-Jan    19°C  4-Jan  18.9°C  4-Jan    19°C
# 4  5-Jan  17.4°C  5-Jan  18.8°C  5-Jan  18.8°C  5-Jan    19°C  5-Jan    19°C
#
#    ... Day.12    2019 Day.13    2020 Day.14    2021 Day.15    2022 Day.16  \
# 0  ...  1-Jan  18.9°C  1-Jan  18.9°C  1-Jan  19.5°C  1-Jan    19°C  1-Jan
# 1  ...  2-Jan  18.7°C  2-Jan  18.8°C  2-Jan    20°C  2-Jan  19.5°C  2-Jan
# 2  ...  3-Jan    19°C  3-Jan  18.9°C  3-Jan  19.9°C  3-Jan  19.2°C  3-Jan
# 3  ...  4-Jan  19.2°C  4-Jan    19°C  4-Jan  19.6°C  4-Jan  19.3°C  4-Jan
# 4  ...  5-Jan  19.2°C  5-Jan  18.9°C  5-Jan  19.5°C  5-Jan  19.2°C  5-Jan
#
#      2023
# 0  19.7°C
# 1  19.8°C
# 2  19.8°C
# 3  19.7°C
# ...

# %% [markdown]
# ## Droping the dates which is useless as will be used only 1 feature as Date.

# %%
drop_cols2 = ["Day.1", "Day.2", "Day.3", "Day.4", "Day.5", "Day.6", "Day.7", "Day.8", "Day.9", "Day.10", "Day.11", "Day.12", "Day.13", "Day.14", "Day.15", "Day.16"]
df = df.drop(columns=drop_cols2)
df.head()
# Out:
#      Day    2007    2008    2009    2010    2011    2012    2013    2014  \
# 0  1-Jan  17.9°C  18.5°C  19.6°C    19°C  19.6°C  18.1°C  18.3°C  17.8°C
# 1  2-Jan  17.9°C  18.3°C  19.5°C  19.1°C  19.4°C  18.1°C  18.8°C  17.7°C
# 2  3-Jan  17.7°C  18.7°C  19.2°C  19.1°C  19.1°C  18.1°C  18.8°C  17.7°C
# 3  4-Jan  17.5°C  19.1°C    19°C  18.9°C    19°C  17.9°C  18.7°C  17.7°C
# 4  5-Jan  17.4°C  18.8°C  18.8°C    19°C    19°C  17.9°C  18.7°C  17.7°C
#
#      2015    2016    2017    2018    2019    2020    2021    2022    2023
# 0    19°C  18.2°C  17.9°C  19.3°C  18.9°C  18.9°C  19.5°C    19°C  19.7°C
# 1  18.9°C    18°C  17.8°C  19.2°C  18.7°C  18.8°C    20°C  19.5°C  19.8°C
# 2  18.8°C  17.9°C  17.7°C  19.1°C    19°C  18.9°C  19.9°C  19.2°C  19.8°C
# 3  18.6°C  17.8°C  17.7°C  19.2°C  19.2°C    19°C  19.6°C  19.3°C  19.7°C
# 4  18.4°C  18.1°C  17.7°C  19.2°C  19.2°C  18.9°C  19.5°C  19.2°C  19.7°C

# %% [markdown]
# # Now will clean the observations

# %% [markdown]
# ### To be sure dopping null values if exist in our dataset

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 377 entries, 0 to 410
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Day     377 non-null    object
#  1   2007    377 non-null    object
#  2   2008    377 non-null    object
#  3   2009    377 non-null    object
#  4   2010    377 non-null    object
#  5   2011    377 non-null    object
#  6   2012    377 non-null    object
#  7   2013    377 non-null    object
#  8   2014    377 non-null    object
#  9   2015    377 non-null    object
#  10  2016    377 non-null    object
#  11  2017    377 non-null    object
#  12  2018    377 non-null    object
#  13  2019    377 non-null    object
#  14  2020    377 non-null    object
#  15  2021    377 non-null    object
#  16  2022    377 non-null    object
#  17  2023    377 non-null    object
# dtypes: object(18)
# memory usage: 56.0+ KB

# %% [markdown]
# ###  We can use set_option to have a look at the full dataset and continue processing needed changes

# %%
pd.set_option("display.max_rows", None)

# %% [markdown]
# ## drop some observations that is not needed.

# %%
drop_rows = [18, 53, 85, 120, 154, 189, 223, 258, 293, 325, 360, 394]
df.drop(drop_rows, inplace=True)
df.head()
# Out:
#      Day    2007    2008    2009    2010    2011    2012    2013    2014  \
# 0  1-Jan  17.9°C  18.5°C  19.6°C    19°C  19.6°C  18.1°C  18.3°C  17.8°C
# 1  2-Jan  17.9°C  18.3°C  19.5°C  19.1°C  19.4°C  18.1°C  18.8°C  17.7°C
# 2  3-Jan  17.7°C  18.7°C  19.2°C  19.1°C  19.1°C  18.1°C  18.8°C  17.7°C
# 3  4-Jan  17.5°C  19.1°C    19°C  18.9°C    19°C  17.9°C  18.7°C  17.7°C
# 4  5-Jan  17.4°C  18.8°C  18.8°C    19°C    19°C  17.9°C  18.7°C  17.7°C
#
#      2015    2016    2017    2018    2019    2020    2021    2022    2023
# 0    19°C  18.2°C  17.9°C  19.3°C  18.9°C  18.9°C  19.5°C    19°C  19.7°C
# 1  18.9°C    18°C  17.8°C  19.2°C  18.7°C  18.8°C    20°C  19.5°C  19.8°C
# 2  18.8°C  17.9°C  17.7°C  19.1°C    19°C  18.9°C  19.9°C  19.2°C  19.8°C
# 3  18.6°C  17.8°C  17.7°C  19.2°C  19.2°C    19°C  19.6°C  19.3°C  19.7°C
# 4  18.4°C  18.1°C  17.7°C  19.2°C  19.2°C  18.9°C  19.5°C  19.2°C  19.7°C

# %% [markdown]
# ## After dropping previous observations/rows, their places will be null so let's frop the nulls

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365 entries, 0 to 410
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Day     365 non-null    object
#  1   2007    365 non-null    object
#  2   2008    365 non-null    object
#  3   2009    365 non-null    object
#  4   2010    365 non-null    object
#  5   2011    365 non-null    object
#  6   2012    365 non-null    object
#  7   2013    365 non-null    object
#  8   2014    365 non-null    object
#  9   2015    365 non-null    object
#  10  2016    365 non-null    object
#  11  2017    365 non-null    object
#  12  2018    365 non-null    object
#  13  2019    365 non-null    object
#  14  2020    365 non-null    object
#  15  2021    365 non-null    object
#  16  2022    365 non-null    object
#  17  2023    365 non-null    object
# dtypes: object(18)
# memory usage: 54.2+ KB

# %% [markdown]
# ## Reset the index for clear data

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# # Our Dataset is almost perfect! but not yet....

# %% [markdown]
# ## As ML will be used so we need to change the datatype to be float

# %% [markdown]
# ## First step here let's delete the "°C" so later on we can have numerial values

# %%
df["2007"] = df["2007"].str.replace("°C","")
df["2008"] = df["2008"].str.replace("°C","")
df["2009"] = df["2009"].str.replace("°C","")
df["2010"] = df["2010"].str.replace("°C","")
df["2011"] = df["2011"].str.replace("°C","")
df["2012"] = df["2012"].str.replace("°C","")
df["2013"] = df["2013"].str.replace("°C","")
df["2014"] = df["2014"].str.replace("°C","")
df["2015"] = df["2015"].str.replace("°C","")
df["2016"] = df["2016"].str.replace("°C","")
df["2017"] = df["2017"].str.replace("°C","")
df["2018"] = df["2018"].str.replace("°C","")
df["2019"] = df["2019"].str.replace("°C","")
df["2020"] = df["2020"].str.replace("°C","")
df["2021"] = df["2021"].str.replace("°C","")
df["2022"] = df["2022"].str.replace("°C","")
df["2023"] = df["2023"].str.replace("°C","")
df.head()
# Out:
#      Day  2007  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  \
# 0  1-Jan  17.9  18.5  19.6    19  19.6  18.1  18.3  17.8    19  18.2  17.9
# 1  2-Jan  17.9  18.3  19.5  19.1  19.4  18.1  18.8  17.7  18.9    18  17.8
# 2  3-Jan  17.7  18.7  19.2  19.1  19.1  18.1  18.8  17.7  18.8  17.9  17.7
# 3  4-Jan  17.5  19.1    19  18.9    19  17.9  18.7  17.7  18.6  17.8  17.7
# 4  5-Jan  17.4  18.8  18.8    19    19  17.9  18.7  17.7  18.4  18.1  17.7
#
#    2018  2019  2020  2021  2022  2023
# 0  19.3  18.9  18.9  19.5    19  19.7
# 1  19.2  18.7  18.8    20  19.5  19.8
# 2  19.1    19  18.9  19.9  19.2  19.8
# 3  19.2  19.2    19  19.6  19.3  19.7
# 4  19.2  19.2  18.9  19.5  19.2  19.7

# %%
# df.to_csv(r"C:\Users\hp\Desktop\Apply\sst-stat-SST.csv")

# %% [markdown]
# # This is easier way to recall each year by assigning df7 for 2007 ... df8 for 2008 and so on....
#
# ## it is not necessary as we still can recall it by df["2007"] but make the job easier for next steps.

# %%
df7 = df[["Day", "2007"]]
df8 = df[["Day", "2008"]]
df9 = df[["Day", "2009"]]
df10 = df[["Day", "2010"]]
df11 = df[["Day", "2011"]]
df12 = df[["Day", "2012"]]
df13 = df[["Day", "2013"]]
df14 = df[["Day", "2014"]]
df15 = df[["Day", "2015"]]
df16 = df[["Day", "2016"]]
df17 = df[["Day", "2017"]]
df18 = df[["Day", "2018"]]
df19 = df[["Day", "2019"]]
df20 = df[["Day", "2020"]]
df21 = df[["Day", "2021"]]
df22 = df[["Day", "2022"]]
df23 = df[["Day", "2023"]]

df7.head()
# Out:
#      Day  2007
# 0  1-Jan  17.9
# 1  2-Jan  17.9
# 2  3-Jan  17.7
# 3  4-Jan  17.5
# 4  5-Jan  17.4

# %% [markdown]
# # for date of each day the year is added as it was not

# %% [markdown]
# ### note: It is called Date and and it used df["Day"] = the year

# %%
# This step we will add for each observation in the Day feature "-2007" and so on so we have more clear with full date
df7["Date"] = df7["Day"] + "-2007"
df8["Date"] = df8["Day"] + "-2008"
df9["Date"] = df9["Day"] + "-2009"
df10["Date"] = df10["Day"] + "-2010"
df11["Date"] = df11["Day"] + "-2011"
df12["Date"] = df12["Day"] + "-2012"
df13["Date"] = df13["Day"] + "-2013"
df14["Date"] = df14["Day"] + "-2014"
df15["Date"] = df15["Day"] + "-2015"
df16["Date"] = df16["Day"] + "-2016"
df17["Date"] = df17["Day"] + "-2017"
df18["Date"] = df18["Day"] + "-2018"
df19["Date"] = df19["Day"] + "-2019"
df20["Date"] = df20["Day"] + "-2020"
df21["Date"] = df21["Day"] + "-2021"
df22["Date"] = df22["Day"] + "-2022"
df23["Date"] = df23["Day"] + "-2023"
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_21564\3943527319.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7["Date"] = df7["Day"] + "-2007"
# C:\Users\hp\AppData\Local\Temp\ipykernel_21564\3943527319.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df8["Date"] = df8["Day"] + "-2008"
# C:\Users\hp\AppData\Local\Temp\ipykernel_21564\3943527319.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Day     365 non-null    object
#  1   2007    365 non-null    object
#  2   Date    365 non-null    object
# dtypes: object(3)
# memory usage: 8.7+ KB

# %% [markdown]
# # Now Day is not used anymore as we have Date and the arrangement should start with Date:

# %%
df7 = df7.drop("Day", axis="columns")
df7 = df7[["Date", "2007"]]
df7.head()
# Out:
#          Date  2007
# 0  1-Jan-2007  17.9
# 1  2-Jan-2007  17.9
# 2  3-Jan-2007  17.7
# 3  4-Jan-2007  17.5
# 4  5-Jan-2007  17.4

# %%
# as we did priously. we will drop "Day" column and the re-arrange the columns to be as same as 2007.
df8 = df8.drop("Day", axis="columns")
df8 = df8[["Date", "2008"]]

df9 = df9.drop("Day", axis="columns")
df9 = df9[["Date", "2009"]]

df10 = df10.drop("Day", axis="columns")
df10 = df10[["Date", "2010"]]

df11 = df11.drop("Day", axis="columns")
df11 = df11[["Date", "2011"]]

df12 = df12.drop("Day", axis="columns")
df12 = df12[["Date", "2012"]]

df13 = df13.drop("Day", axis="columns")
df13 = df13[["Date", "2013"]]

df14 = df14.drop("Day", axis="columns")
df14 = df14[["Date", "2014"]]

df15 = df15.drop("Day", axis="columns")
df15 = df15[["Date", "2015"]]

df16 = df16.drop("Day", axis="columns")
df16 = df16[["Date", "2016"]]

df17 = df17.drop("Day", axis="columns")
df17 = df17[["Date", "2017"]]

df18 = df18.drop("Day", axis="columns")
df18 = df18[["Date", "2018"]]

df19 = df19.drop("Day", axis="columns")
df19 = df19[["Date", "2019"]]

df20 = df20.drop("Day", axis="columns")
df20 = df20[["Date", "2020"]]

df21 = df21.drop("Day", axis="columns")
df21 = df21[["Date", "2021"]]

df22 = df22.drop("Day", axis="columns")
df22 = df22[["Date", "2022"]]

df23 = df23.drop("Day", axis="columns")
df23 = df23[["Date", "2023"]]

# %% [markdown]
# ## let's change the data type to float so we can have numerical data in SST columns

# %%
df23["2023"] = df23["2023"].astype(float)
df22["2022"] = df22["2022"].astype(float)
df21["2021"] = df21["2021"].astype(float)
df20["2020"] = df20["2020"].astype(float)
df19["2019"] = df19["2019"].astype(float)
df18["2018"] = df18["2018"].astype(float)
df17["2017"] = df17["2017"].astype(float)
df16["2016"] = df16["2016"].astype(float)
df15["2015"] = df15["2015"].astype(float)
df14["2014"] = df14["2014"].astype(float)
df13["2013"] = df13["2013"].astype(float)
df12["2012"] = df12["2012"].astype(float)
df11["2011"] = df11["2011"].astype(float)
df10["2010"] = df10["2010"].astype(float)
df9["2009"] = df9["2009"].astype(float)
df8["2008"] = df8["2008"].astype(float)
df7["2007"] = df7["2007"].astype(float)

df13.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    365 non-null    object
#  1   2013    365 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 5.8+ KB

# %% [markdown]
# ## Also let's change the Date feature to date_time instead of object

# %%
df23['Date'] = pd.to_datetime(df23['Date'])
df22['Date'] = pd.to_datetime(df22['Date'])
df21['Date'] = pd.to_datetime(df21['Date'])
df20['Date'] = pd.to_datetime(df20['Date'])
df19['Date'] = pd.to_datetime(df18['Date'])
df18['Date'] = pd.to_datetime(df17['Date'])
df17['Date'] = pd.to_datetime(df16['Date'])
df16['Date'] = pd.to_datetime(df15['Date'])
df15['Date'] = pd.to_datetime(df14['Date'])
df14['Date'] = pd.to_datetime(df13['Date'])
df13['Date'] = pd.to_datetime(df12['Date'])
df12['Date'] = pd.to_datetime(df11['Date'])
df10['Date'] = pd.to_datetime(df10['Date'])
df9['Date'] = pd.to_datetime(df9['Date'])
df8['Date'] = pd.to_datetime(df8['Date'])
df7['Date'] = pd.to_datetime(df7['Date'])
df9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    365 non-null    datetime64[ns]
#  1   2009    365 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 5.8 KB

# %% [markdown]
# # The dataset is ready!!
# ## Let's try some EDA and some Statistics on it for each year. The aim is to compare between years.....

# %% [markdown]
# ## Will start with Histogram for each year with have a standard limit to 100 and the bins as 14 using matplot library

# %%
# Create the histogram
plt.hist(df7["2007"], bins=14, edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("SST (in Celsius)")
plt.ylabel("Frequency")
plt.title("Histogram: SST for 2007 (Daily Basis)")

# Set the y-axis limit to 100
plt.ylim(0, 100)

# Show the plot
plt.grid(True)
plt.show()

# %%
# plt.boxplot(df7["2007"], vert=True)
# plt.ylabel("SST IN CELSIUS")
# plt.title("Boxplot: SST in 2007")

# %%
# Create the histogram
plt.hist(df8["2008"], bins=14, edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("SST (in Celsius)")
plt.ylabel("Frequency")
plt.title("Histogram: SST for 2008 (Daily Basis)")

# Set the y-axis limit to 100
plt.ylim(0, 100)

# Show the plot
plt.grid(True)
plt.show()

# %%
# plt.boxplot(df8["2008"], vert=True)
# plt.ylabel("SST IN CELSIUS")
# plt.title("Boxplot: SST in 2008")

# %%
# Create the histogram
plt.hist(df9["2009"], bins=14, edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("SST (in Celsius)")
plt.ylabel("Frequency")
plt.title("Histogram: SST for 2009 (Daily Basis)")

# Set the y-axis limit to 100
plt.ylim(0, 100)

# Show the plot
plt.grid(True)
plt.show()

# %%
# plt.boxplot(df9["2009"], vert=True)
# plt.ylabel("SST IN CELSIUS")
# plt.title("Boxplot: SST in 2009")

# %%
# Create the histogram
plt.hist(df10["2010"], bins=14, edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("SST (in Celsius)")
plt.ylabel("Frequency")
plt.title("Histogram: SST for 2010 (Daily Basis)")

# Set the y-axis limit to 100
plt.ylim(0, 100)

# Show the plot
plt.grid(True)
plt.show()

# %%
# plt.boxplot(df10["2010"], vert=True)
# plt.ylabel("SST IN CELSIUS")
# plt.title("Boxplot: SST in 2010")

# %%
# Create the histogram
plt.hist(df11["2011"], bins=14, edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("SST (in Celsius)")
plt.ylabel("Frequency")
plt.title("Histogram: SST for 2011 (Daily Basis)")

# Set the y-axis limit to 100
plt.ylim(0, 100)

# Show the plot
plt.grid(True)
plt.show()

# %%
# plt.boxplot(df11["2011"], vert=True)
# plt.ylabel("SST IN CELSIUS")
# plt.title("Boxplot: SST in 2011")

# %%
# Create the histogram
plt.hist(df12["2012"], bins=14, edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("SST (in Celsius)")
plt.ylabel("Frequency")
plt.title("Histogram: SST for 2012 (Daily Basis)")

# Set the y-axis limit to 100
plt.ylim(0, 100)

# Show the plot
plt.grid(True)
plt.show()

# %%
# plt.boxplot(df12["2012"], vert=True)
# plt.ylabel("SST IN CELSIUS")
# plt.title("Boxplot: SST in 2012")

# %%
# Create the histogram
plt.hist(df13["2013"], bins=14, edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("SST (in Celsius)")
plt.ylabel("Frequency")
plt.title("Histogram: SST for 2013 (Daily Basis)")

# Set the y-axis limit to 100
plt.ylim(0, 100)

# Show the plot
plt.grid(True)
plt.show()

# %%
# plt.boxplot(df13["2013"], vert=True)
# plt.ylabel("SST IN CELSIUS")
# plt.title("Boxplot: SST in 2013")

# %%
# Create the histogram
plt.hist(df14["2014"], bins=14, edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("SST (in Celsius)")
plt.ylabel("Frequency")
plt.title("Histogram: SST for 2014 (Daily Basis)")

# Set the y-axis limit to 100
plt.ylim(0, 100)

# Show the plot
plt.grid(True)
plt.show()

# %%
# plt.boxplot(df14["2014"], vert=True)
# plt.ylabel("SST IN CELSIUS")
# plt.title("Boxplot: SST in 2014")

# %%
# Create the histogram
plt.hist(df15["2015"], bins=14, edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("SST (in Celsius)")
plt.ylabel("Frequency")
plt.title("Histogram: SST for 2015 (Daily Basis)")

# Set the y-axis limit to 100
plt.ylim(0, 100)

# Show the plot
plt.grid(True)
plt.show()

# %%
# plt.boxplot(df15["2015"], vert=True)
# plt.ylabel("SST IN CELSIUS")
# plt.title("Boxplot: SST in 2015")

# %%
# Create the histogram
plt.hist(df16["2016"], bins=14, edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("SST (in Celsius)")
plt.ylabel("Frequency")
plt.title("Histogram: SST for 2016 (Daily Basis)")

# Set the y-axis limit to 100
plt.ylim(0, 100)

# Show the plot
plt.grid(True)
plt.show()

# %%
# plt.boxplot(df16["2016"], vert=True)
# plt.ylabel("SST IN CELSIUS")
# plt.title("Boxplot: SST in 2016")

# %%
# Create the histogram
plt.hist(df17["2017"], bins=14, edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("SST (in Celsius)")
plt.ylabel("Frequency")
plt.title("Histogram: SST for 2017 (Daily Basis)")

# Set the y-axis limit to 100
plt.ylim(0, 100)

# Show the plot
plt.grid(True)
plt.show()

# %%
# plt.boxplot(df17["2017"], vert=True)
# plt.ylabel("SST IN CELSIUS")
# plt.title("Boxplot: SST in 2017")

# %%
# Create the histogram
plt.hist(df18["2018"], bins=14, edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("SST (in Celsius)")
plt.ylabel("Frequency")
plt.title("Histogram: SST for 2018 (Daily Basis)")

# Set the y-axis limit to 100
plt.ylim(0, 100)

# Show the plot
plt.grid(True)
plt.show()

# %%
# plt.boxplot(df18["2018"], vert=True)
# plt.ylabel("SST IN CELSIUS")
# plt.title("Boxplot: SST in 2018")

# %%
# Create the histogram
plt.hist(df19["2019"], bins=14, edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("SST (in Celsius)")
plt.ylabel("Frequency")
plt.title("Histogram: SST for 2019 (Daily Basis)")

# Set the y-axis limit to 100
plt.ylim(0, 100)

# Show the plot
plt.grid(True)
plt.show()

# %%
# plt.boxplot(df19["2019"], vert=True)
# plt.ylabel("SST IN CELSIUS")
# plt.title("Boxplot: SST in 2019")

# %%
# Create the histogram
plt.hist(df20["2020"], bins=14, edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("SST (in Celsius)")
plt.ylabel("Frequency")
plt.title("Histogram: SST for 2020 (Daily Basis)")

# Set the y-axis limit to 100
plt.ylim(0, 100)

# Show the plot
plt.grid(True)
plt.show()

# %%
# plt.boxplot(df20["2020"], vert=True)
# plt.ylabel("SST IN CELSIUS")
# plt.title("Boxplot: SST in 2020")

# %%
# Create the histogram
plt.hist(df21["2021"], bins=14, edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("SST (in Celsius)")
plt.ylabel("Frequency")
plt.title("Histogram: SST for 2021 (Daily Basis)")

# Set the y-axis limit to 100
plt.ylim(0, 100)

# Show the plot
plt.grid(True)
plt.show()

# %%
# plt.boxplot(df21["2021"], vert=True)
# plt.ylabel("SST IN CELSIUS")
# plt.title("Boxplot: SST in 2021")

# %%
# Create the histogram
plt.hist(df22["2022"], bins=14, edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("SST (in Celsius)")
plt.ylabel("Frequency")
plt.title("Histogram: SST for 2022 (Daily Basis)")

# Set the y-axis limit to 100
plt.ylim(0, 100)

# Show the plot
plt.grid(True)
plt.show()

# %%
# plt.boxplot(df22["2022"], vert=True)
# plt.ylabel("SST IN CELSIUS")
# plt.title("Boxplot: SST in 2022")

# %%
# Create the histogram
plt.hist(df23["2023"], bins=14, edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("SST (in Celsius)")
plt.ylabel("Frequency")
plt.title("Histogram: SST for 2023 (Daily Basis)")

# Set the y-axis limit to 100
plt.ylim(0, 100)

# Show the plot
plt.grid(True)
plt.show()

# %%
# plt.boxplot(df23["2023"], vert=True)
# plt.ylabel("SST IN CELSIUS")
# plt.title("Boxplot: SST in 2023")

# %%
import pandas as pd
pd.reset_option("display.max_rows")

# %%
path_sst = r"C:\Users\hp\Desktop\Apply\SST2007-SST2023-1time.csv"
df_SST = pd.read_csv(path_sst)
df_SST.head()
# Out:
#    SST2007  SST2008  SST2009  SST2010  SST2011  SST2012  SST2013  SST2014  \
# 0     17.9     18.5     19.6     19.0     19.6     18.1     18.3     17.8
# 1     17.9     18.3     19.5     19.1     19.4     18.1     18.8     17.7
# 2     17.7     18.7     19.2     19.1     19.1     18.1     18.8     17.7
# 3     17.5     19.1     19.0     18.9     19.0     17.9     18.7     17.7
# 4     17.4     18.8     18.8     19.0     19.0     17.9     18.7     17.7
#
#    SST2015  SST2016  SST2017  SST2018  SST2019  SST2020  SST2021  SST2022  \
# 0     19.0     18.2     17.9     19.3     18.9     18.9     19.5     19.0
# 1     18.9     18.0     17.8     19.2     18.7     18.8     20.0     19.5
# 2     18.8     17.9     17.7     19.1     19.0     18.9     19.9     19.2
# 3     18.6     17.8     17.7     19.2     19.2     19.0     19.6     19.3
# 4     18.4     18.1     17.7     19.2     19.2     18.9     19.5     19.2
#
#    SST2023
# 0     19.7
# 1     19.8
# 2     19.8
# 3     19.7
# 4     19.7

# %% [markdown]
# # Boxplot for each year, in one plot whih is easier to compare results this way

# %%
#now instead of having boxplot for eah year, i will add boxplot for each year but in one plot whih is easier to compare results this way
plt.boxplot(df_SST, vert=True)
plt.xlabel("1 is 2007   -------    17 is 2023")
plt.ylabel("SST in Celsius")
plt.title("Boxplot: SST for 2007-2023")
# Out:
# Text(0.5, 1.0, 'Boxplot: SST for 2007-2023')

# %% [markdown]
# # let's have basis statistical description for our dataset:

# %%
df_SST.describe()
# Out:
#           SST2007     SST2008     SST2009     SST2010     SST2011     SST2012  \
# count  365.000000  365.000000  365.000000  365.000000  365.000000  365.000000
# mean    21.895616   22.265479   22.351507   22.677534   22.347671   22.729589
# std      4.680141    4.618229    4.390634    4.450014    4.386803    4.814419
# min     15.300000   15.800000   16.300000   16.200000   16.800000   16.100000
# 25%     16.900000   18.000000   18.000000   18.500000   18.300000   17.700000
# 50%     21.300000   21.700000   22.100000   22.000000   20.600000   22.600000
# 75%     26.500000   26.600000   26.400000   26.900000   26.600000   27.700000
# max     29.500000   30.600000   29.800000   31.000000   29.900000   30.700000
#
#           SST2013     SST2014     SST2015     SST2016     SST2017     SST2018  \
# count  365.000000  365.000000  365.000000  365.000000  365.000000  365.000000
# mean    22.244932   22.476986   22.664384   22.693151   22.492055   23.152055
# ...

# %% [markdown]
# # Further Statistics on the datset such as variation/trimmed variation/mean/median

# %% [markdown]
# ### This is after concating/merging the data to have Date as daily basis starts from 1st jan 2007 and ends 31 dec 2023

# %%
path = (r"C:\Users\hp\Research-Try-ML\SST-Antalya-2007-2023-Cleaned -Sample.csv")
df_concat = pd.read_csv(path)
df_concat.head()
# Out:
#        Date   SST
# 0  1-Jan-07  17.9
# 1  2-Jan-07  17.9
# 2  3-Jan-07  17.7
# 3  4-Jan-07  17.5
# 4  5-Jan-07  17.4

# %% [markdown]
# ## Variance

# %%
#using from scipy import stats library
df_concat["SST"].var()
# Out:
# 20.452251661608866

# %% [markdown]
# ## trimmed_variance

# %%
#trimmed variance is by excluding the min and max values.
from scipy import stats
stats.mstats.trimmed_var(df_concat["SST"])
# Out:
# 15.146625604204257

# %% [markdown]
# ##  Mean and Median

# %%
#Also it is usefull to compare the mean and the median
print("Mean value is:", df_concat["SST"].agg("mean"))
print("Median value is:", df_concat["SST"].agg("median"))
# Out:
# Mean value is: 22.58222401289283
# Median value is: 22.1

# %% [markdown]
# # Hiostogram to see the frequency of the SST in Celsius

# %%
plt.hist(df_concat["SST"], bins=14, edgecolor="black", alpha=0.7)

# Customize the plot
plt.xlabel("SST (in Celsius)")
plt.ylabel("Frequency")
plt.title("Histogram: SST for 2007-2023 (Daily Basis)")


# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# ## This result of dataset will be merged with weather forecasts data and then apply Machine Learning Models on it.
# ### With kindest Regards.
# ## Abdallah I. J. Dwikat
# ### email: adweikat12@gmail.com  /   linkedin: Abdallah Dwikat
